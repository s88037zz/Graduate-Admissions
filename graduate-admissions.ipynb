# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#load data
data = pd.read_csv("C:\\Users\\user\\Desktop\\DataScience\\graduate-admissions\\Admission_Predict.csv")

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
#Data Understanding
    #There is 400 Observations of 9 Variable
    #ㄒThere is mix of Integer and Numeric DataType
    #Dependent Variable is Chance.of.Admit
    #Independent Variables are:GRE.Score, TOEFL.Score,University.Rating,SOP,LOR,CGPA and Research.
    #Minimum Chance of Admission is 34% and Maximum is 97%. Average Chance of Admissioni is 72%.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
# Serial No.           400 non-null int64
# GRE Score            400 non-null int64
# TOEFL Score          400 non-null int64
# University Rating    400 non-null int64
# SOP                  400 non-null float64
# LOR                  400 non-null float64
# CGPA                 400 non-null float64
# Research             400 non-null int64
# Chance of Admit      400 non-null float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
#Correlation between ALL Columns
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df.corr(), ax = ax, annot=True, linewidths = 0.05,
            fmt='.2f', cmap="magma")
plt.show()
#The 3 most important features for admission to the Master: CGPA, GRE SCORE, and TOEFL SCORE
#The 3 least important features for admission to the Master: Research, LOR, and SOP

# %%
print("Not Having Research:", len(df[df.Research == 0]))
X = ["Not Having Research", "Having Research"]
